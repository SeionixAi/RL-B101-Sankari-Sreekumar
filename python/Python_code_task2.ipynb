# %%
Python Coding Tasks
1. Dynamic Typing
Write a program that:
* Assigns an integer value to a variable
* Reassigns a string value to the same variable
* Prints the value and its type at each step
x = 10
print(x, type(x))

x = "Hello Python"
print(x, type(x))

2. Mutable vs Immutable Data Types
Write a program that:
* Modifies a list
* Attempts to modify a tuple��
my_list = [1, 2, 3]
my_list[0] = 10
print(my_list)

my_tuple = (1, 2, 3)
# my_tuple[0] = 10
print(my_tuple)

3. Local and Global Variables
Write a program that:
* Uses a global variable
* Uses a local variable inside a function
x = 100

def demo():
    y = 50
    print(x, y)

demo()

4. Return Statement in a Function
Write a function that:
* Takes two numbers
* Returns their sum


5. List Comprehension
Write a program that:
* Creates a list of squares from 1 to 10
squares = [x * x for x in range(1, 11)]
print(squares)

6. break, continue, and pass
Write a program that:
* Demonstrates break, continue, and pass
for i in range(1, 11):
    if i == 3:
        continue
    if i == 5:
        break
    if i == 7:
        pass
    print(i)

7. Recursion
Write a recursive function that:
* Finds the factorial of a number
def factorial(n):
    if n == 0:
        return 1
    return n * factorial(n - 1)

print(factorial(5))

8. Lambda Function
Write a lambda function that:
* Returns the square of a number��


9. is vs ==
Write a program that:
* Compares two lists using == and is


10. Docstrings
Write a function that:
* Uses a docstring
def greet():
    """This function prints a greeting message"""
    print("Hello Python")

greet()
print(greet.__doc__)

# %%
import pandas as pd
import numpy as np

# %%
x = 10
print(x, type(x))

x = "Hello Python"
print(x, type(x))
# Out:
# 10 <class 'int'>
# Hello Python <class 'str'>

# %%
L=[1,2,3,4]
L[0]=0
print(L)
# Out:
# [0, 2, 3, 4]

# %%
T=(1,2,3)
T[0]=0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3529342510.py in <cell line: 0>()
#       1 T=(1,2,3)
# ----> 2 T[0]=0
#
# TypeError: 'tuple' object does not support item assignment

# %%
X=2
def demo():
   Y=4
   print(X,Y)
demo()
# Out:
# 2 4

# %%
print (X), print (Y)
# Out:
# 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1590963992.py in <cell line: 0>()
# ----> 1 print (X), print (Y)
#
# NameError: name 'Y' is not defined

# %%
def add(a, b):
    return a + b

result = add(5, 3)
print(result)
# Out:
# 8

# %%
squares = [x * x for x in range(1, 11)]
print(squares)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
for i in range(1, 11):
    if i == 3:
        continue
    if i == 5:
        break
    if i == 7:
        pass
    print(i)
# Out:
# 1
# 2
# 4

# %%
def factorial(n):
    if n == 0:
        return 1
    return n * factorial(n - 1)
print(factorial(5))
# Out:
# 120

# %%
square = lambda x: x * x
print(square(4))
# Out:
# 16

# %%
a = [1, 2, 3]
b = [1, 2, 3]

print(a == b)
print(a is b)
# Out:
# True
# False

# %%
def greet():
    """This function prints a greeting message"""
    print("Hello Python")

greet()
print(greet.__doc__)
# Out:
# Hello Python
# This function prints a greeting message

# %%
def greet():
    """This function prints a greeting message"""
    print("Hello Python")

greet()
# Out:
# Hello Python

# %%
def greet():
    """This function prints a greeting message"""
    print("Hello Python")

greet()
print(greet)
# Out:
# Hello Python
# <function greet at 0x7efeb0706ca0>
