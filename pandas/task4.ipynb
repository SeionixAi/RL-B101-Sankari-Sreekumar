# %%
import pandas as pd
import numpy as np

# %% [markdown]
# COUNT THE NUMBER OF VOWELS

# %%
def count_vowels(text):
  count=0
  vowels="aeiou"
  for i in text:
    if i in vowels:
      count+=1
  return count
#count_vowels("machine ")
print(count_vowels("machine "))
#print(count)
# Out:
# 3

# %%
def count_vowels(text):
    vowels = "aeiou"
    count = 0
    for char in text.lower():
        if char in vowels:
            count += 1
    return count

# Example
print(count_vowels("Artificial Intelligence"))
# Out:
# 10

# %% [markdown]
# CHECK A STINH IS PA

# %%
A="mamam"
Reversed=A[::-1]
def is_palindrome():
  if A ==Reversed:
    print("t")
  else:
     print("f")
is_palindrome()
# Out:
# t

# %% [markdown]
# CHECK A STRING IS ANAGRAMS

# %%
def is_anagram(s1,s2):
  str1=s1.lower()
  str2=s2.lower()
  sorted_str1=sorted(str1)
  sorted_str2=sorted(str2)
  if sorted_str1==sorted_str2:
    print("strings are anagrams")
  else:
    print("strings are not anagrams")
is_anagram("listen","silent")
# Out:
# strings are anagrams
