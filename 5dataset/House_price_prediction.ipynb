# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 🔹 Real-World Context
#
# This dataset contains house sales information from King County, USA.
# It includes house features like bedrooms, bathrooms, square footage, location, and more.

# %% [markdown]
# 🔹 Problem Statement
#
# Predict the selling price (price) of a house based on its features.

# %% [markdown]
# load dataset

# %%
df=pd.read_csv('/content/kc_house_data.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %%
df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608      1530.0              0      2009             0    98103  47.6993
# ...

# %%
df.sample(3)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1209   3971700560  20150421T000000   392400.0         5       2.50
# 19125  4323700230  20140818T000000   390000.0         4       1.75
# 21141  8923600020  20140806T000000  1880000.0         5       3.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1209          2520     27951     1.5           0     0  ...      7
# 19125         2020      9750     1.0           0     0  ...      7
# 21141         4390      6220     2.0           0     3  ...      9
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 1209       1890.0            630      1942          1970    98155  47.7733
# 19125      1100.0            920      1975             0    98074  47.6192
# 21141      3170.0           1220      2013             0    98115  47.6789
#
#           long  sqft_living15  sqft_lot15
# 1209  -122.318           1830       14373
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21611 non-null  float64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       2
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df = df.dropna(subset=['sqft_above'])

# %% [markdown]
# The sqft_above column contained only 2 missing values (less than 0.01% of the dataset).
# Since the missing proportion is extremely small, the affected rows were removed to maintain data integrity without impacting model performance.

# %%
df.isnull().sum()
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# sale_year        0
# sale_month       0
# house_age        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Data Preprocessing

# %%
df.drop('id',axis=1,inplace=True)

# %%
df['date']=pd.to_datetime(df['date'])
df['sale_year']=df['date'].dt.year

df['sale_month']=df['date'].dt.month

# %%
df.drop('date', axis=1, inplace=True)

# %% [markdown]
# Feature Engineering

# %% [markdown]
# Create House Age

# %%
df['house_age']=df['sale_year']-df['yr_built']

# %% [markdown]
# Outlier Treatment
# 🔹 Price Distribution

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(df['price'], kde=True)
plt.title("Distribution of House Prices")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
sns.boxplot(df['price'])
plt.title("Box Plot of House Prices")
plt.xlabel("Price")
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py'>

# %% [markdown]
# Exploratory Data Analysis (EDA)

# %% [markdown]
# 1️⃣ Sqft Living vs Price

# %%
sns.scatterplot(x='sqft_living', y='price', data=df)
plt.title("Living Area vs Price")
plt.xlabel("Living Area")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# Interpretation:
#
# Strong positive relationship — larger homes sell for more.

# %%
sns.boxplot(x='bedrooms', y='price', data=df)
plt.title("Bedrooms vs Price")
plt.show()

# %% [markdown]
# Interpretation:
#
# Price increases up to certain bedroom count, then stabilizes.

# %% [markdown]
# 3️⃣ Waterfront Effect

# %%
sns.boxplot(x='waterfront', y='price', data=df)
plt.title("Waterfront vs Price")
plt.show()

# %% [markdown]
# Interpretation:
#
# Waterfront properties are significantly more expensive

# %%
num_cols = ['bedrooms','bathrooms','sqft_living','sqft_lot','floors',
            'sqft_above','sqft_basement','lat','long',
            'sqft_living15','sqft_lot15','sale_year','sale_month']

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Interpretation:
#
# sqft_living highly correlated with price
#
# sqft_above correlated with sqft_living → multicollinearity
#
# grade strongly affects price

# %% [markdown]
#  Insights & Modeling Readiness
# 🔹 Key Findings
#
# Living area strongly influences price
#
# Grade is a major price determinant
#
# Waterfront adds premium value
#
# Price is right-skewed
#
# 🔹 Modeling Challenges
#
# Skewed target variable
#
# Multicollinearity between square footage features
#
# High number of zipcode dummy variables
