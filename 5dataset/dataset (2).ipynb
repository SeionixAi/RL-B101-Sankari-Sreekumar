# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# load data

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mohitkumar282/used-car-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'used-car-dataset' dataset.
# Path to dataset files: /kaggle/input/used-car-dataset

# %% [markdown]
# view dataset

# %%
df=pd.read_csv('/kaggle/input/used-car-dataset/used_car_dataset.csv')
df.head()
# Out:
#            Brand      model  Year  Age     kmDriven Transmission   Owner  \
# 0          Honda       City  2001   23    98,000 km       Manual  second
# 1         Toyota     Innova  2009   15  190000.0 km       Manual  second
# 2     Volkswagen  VentoTest  2010   14    77,246 km       Manual   first
# 3  Maruti Suzuki      Swift  2017    7    83,500 km       Manual  second
# 4  Maruti Suzuki     Baleno  2019    5    45,000 km    Automatic   first
#
#   FuelType PostedDate                                       AdditionInfo  \
# 0   Petrol     Nov-24  Honda City v teck in mint condition, valid gen...
# 1   Diesel     Jul-24  Toyota Innova 2.5 G (Diesel) 7 Seater, 2009, D...
# 2   Diesel     Nov-24  Volkswagen Vento 2010-2013 Diesel Breeze, 2010...
# 3   Diesel     Nov-24     Maruti Suzuki Swift 2017 Diesel Good Condition
# 4   Petrol     Nov-24       Maruti Suzuki Baleno Alpha CVT, 2019, Petrol
#
#      AskPrice
# 0  ₹ 1,95,000
# 1  ₹ 3,75,000
# 2  ₹ 1,84,999
# 3  ₹ 5,65,000
# 4  ₹ 6,85,000

# %%
df.tail()
# Out:
#               Brand     model  Year  Age    kmDriven Transmission   Owner  \
# 9577          Skoda   Octavia  2014   10  105,904 km    Automatic  second
# 9578  Maruti Suzuki  Alto-800  2020    4   55,000 km       Manual   first
# 9579  Maruti Suzuki      Ritz  2013   11   92,000 km       Manual   first
# 9580        Hyundai     Verna  2019    5   72,000 km    Automatic   first
# 9581        Hyundai   New i20  2021    3   83,228 km       Manual  second
#
#         FuelType PostedDate  \
# 9577      Diesel     Oct-24
# 9578  Hybrid/CNG     Nov-24
# 9579      Diesel     Nov-24
# 9580      Petrol     Oct-24
# 9581      Petrol     Nov-24
#
#                                            AdditionInfo     AskPrice
# 9577       Skoda Octavia 1.9 Elegance TDI, 2014, Diesel  ₹ 10,40,000
# 9578  Maruti Suzuki Alto 800 CNG LXI Optional, 2020,...   ₹ 3,75,000
# 9579               Maruti Suzuki Ritz VDi, 2013, Diesel   ₹ 4,15,000
# 9580  Hyundai Verna VTVT 1.6 AT SX Option, 2019, Petrol   ₹ 8,55,000
# 9581         Hyundai New i20 1.2 Asta IVT, 2021, Petrol   ₹ 6,99,000

# %%
df.sample(3)
# Out:
#               Brand             model  Year  Age     kmDriven Transmission  \
# 4002       Mahindra              Xylo  2011   13  105000.0 km       Manual
# 2284            BMW          5 Series  2016    8    47,000 km    Automatic
# 5854  Maruti Suzuki  Wagon-R-Stingray  2014   10    50,000 km    Automatic
#
#        Owner    FuelType PostedDate  \
# 4002  second      Diesel     Nov-24
# 2284  second      Diesel     Nov-24
# 5854  second  Hybrid/CNG     Nov-24
#
#                                            AdditionInfo     AskPrice
# 4002  Mahindra Xylo 2009-2011 E8 ABS BS IV, 2011, Di...   ₹ 5,50,000
# 2284        BMW 5 Series 3.0 530D M Sport, 2016, Diesel  ₹ 25,00,000
# 5854                Maruti Suzuki Wagon R Stingray 2014   ₹ 3,00,000

# %% [markdown]
# inspect sructure

# %%
df.shape
# Out:
# (9582, 11)

# %%
df.columns
# Out:
# Index(['Brand', 'model', 'Year', 'Age', 'kmDriven', 'Transmission', 'Owner',
#        'FuelType', 'PostedDate', 'AdditionInfo', 'AskPrice'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9582 entries, 0 to 9581
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         9582 non-null   object
#  1   model         9582 non-null   object
#  2   Year          9582 non-null   int64
#  3   Age           9582 non-null   int64
#  4   kmDriven      9535 non-null   object
#  5   Transmission  9582 non-null   object
#  6   Owner         9582 non-null   object
#  7   FuelType      9582 non-null   object
#  8   PostedDate    9582 non-null   object
#  9   AdditionInfo  9582 non-null   object
#  10  AskPrice      9582 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 823.6+ KB

# %%
df.dtypes
# Out:
# Brand           object
# model           object
# Year             int64
# Age              int64
# kmDriven        object
# Transmission    object
# Owner           object
# FuelType        object
# PostedDate      object
# AdditionInfo    object
# AskPrice        object
# dtype: object

# %%
df.describe()
# Out:
#               Year          Age
# count  9582.000000  9582.000000
# mean   2016.361094     7.638906
# std       4.087226     4.087226
# min    1986.000000     0.000000
# 25%    2014.000000     5.000000
# 50%    2017.000000     7.000000
# 75%    2019.000000    10.000000
# max    2024.000000    38.000000

# %% [markdown]
# Handling Missing Data

# %%
df.isnull().sum()
# Out:
# Brand            0
# model            0
# Year             0
# Age              0
# kmDriven        47
# Transmission     0
# Owner            0
# FuelType         0
# PostedDate       0
# AdditionInfo     0
# AskPrice         0
# dtype: int64

# %% [markdown]
# handling duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(724)

# %%
df[df.duplicated()]
# Out:
#               Brand      model  Year  Age     kmDriven Transmission   Owner  \
# 146            Audi         A3  2015    9    42,000 km    Automatic  second
# 152           Honda       City  2016    8    93,000 km    Automatic  second
# 199            Audi         A3  2015    9    42,000 km    Automatic  second
# 221          Toyota      Camry  2015    9    68,000 km    Automatic  second
# 230   Mercedes-Benz  GLE COUPE  2021    3    32,000 km    Automatic  second
# ...             ...        ...   ...  ...          ...          ...     ...
# 9510            BMW         X1  2020    4    45,000 km    Automatic   first
# 9518     Volkswagen  VentoTest  2014   10    72,900 km    Automatic  second
# 9540  Maruti Suzuki  Celerio-X  2020    4   142,000 km    Automatic  second
# 9542  Maruti Suzuki    Celerio  2015    9  103000.0 km    Automatic  second
# 9562            BMW   5 Series  2016    8    47,000 km    Automatic  second
#
#         FuelType PostedDate  \
# 146       Diesel     Nov-24
# 152       Petrol     Nov-24
# 199       Diesel     Nov-24
# 221       Petrol     Nov-24
# 230       Petrol     Oct-24
# ...          ...        ...
# 9510      Petrol     Nov-24
# 9518      Diesel     Nov-24
# 9540  Hybrid/CNG     Nov-24
# 9542      Petrol     Nov-24
# 9562      Diesel     Nov-24
#
#                                            AdditionInfo       AskPrice
# 146         Audi A3 2.0 35 TDI Attraction, 2015, Diesel    ₹ 10,50,000
# 152               Honda City 2016 Petrol Good Condition     ₹ 5,75,000
# 199         Audi A3 2.0 35 TDI Attraction, 2015, Diesel    ₹ 10,50,000
# 221         Toyota Camry 2012-2014 Hybrid, 2015, Petrol    ₹ 11,85,000
# 230   Mercedes-Benz GLE COUPE 3.0 53 AMG 4MATIC Plus...  ₹ 1,18,00,000
# ...                                                 ...            ...
# 9510          BMW X1 2.0 sDrive20i SportX, 2020, Petrol    ₹ 37,00,000
# 9518                             Vento Diesel Automatic     ₹ 5,11,000
# 9540  Maruti Suzuki Celerio X 2020 सीएनजी और अन्य 14...     ₹ 3,20,000
# 9542  Maruti Suzuki Celerio 2014-2017 VXI AT, 2015, ...     ₹ 3,60,000
# 9562        BMW 5 Series 3.0 530D M Sport, 2016, Diesel    ₹ 25,00,000
#
# [724 rows x 11 columns]

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#               Brand      model  Year  Age     kmDriven Transmission   Owner  \
# 0             Honda       City  2001   23    98,000 km       Manual  second
# 1            Toyota     Innova  2009   15  190000.0 km       Manual  second
# 2        Volkswagen  VentoTest  2010   14    77,246 km       Manual   first
# 3     Maruti Suzuki      Swift  2017    7    83,500 km       Manual  second
# 4     Maruti Suzuki     Baleno  2019    5    45,000 km    Automatic   first
# ...             ...        ...   ...  ...          ...          ...     ...
# 9577          Skoda    Octavia  2014   10   105,904 km    Automatic  second
# 9578  Maruti Suzuki   Alto-800  2020    4    55,000 km       Manual   first
# 9579  Maruti Suzuki       Ritz  2013   11    92,000 km       Manual   first
# 9580        Hyundai      Verna  2019    5    72,000 km    Automatic   first
# 9581        Hyundai    New i20  2021    3    83,228 km       Manual  second
#
#         FuelType PostedDate  \
# 0         Petrol     Nov-24
# 1         Diesel     Jul-24
# 2         Diesel     Nov-24
# 3         Diesel     Nov-24
# 4         Petrol     Nov-24
# ...          ...        ...
# 9577      Diesel     Oct-24
# 9578  Hybrid/CNG     Nov-24
# 9579      Diesel     Nov-24
# 9580      Petrol     Oct-24
# 9581      Petrol     Nov-24
#
#                                            AdditionInfo     AskPrice
# 0     Honda City v teck in mint condition, valid gen...   ₹ 1,95,000
# 1     Toyota Innova 2.5 G (Diesel) 7 Seater, 2009, D...   ₹ 3,75,000
# 2     Volkswagen Vento 2010-2013 Diesel Breeze, 2010...   ₹ 1,84,999
# 3        Maruti Suzuki Swift 2017 Diesel Good Condition   ₹ 5,65,000
# 4          Maruti Suzuki Baleno Alpha CVT, 2019, Petrol   ₹ 6,85,000
# ...                                                 ...          ...
# 9577       Skoda Octavia 1.9 Elegance TDI, 2014, Diesel  ₹ 10,40,000
# 9578  Maruti Suzuki Alto 800 CNG LXI Optional, 2020,...   ₹ 3,75,000
# 9579               Maruti Suzuki Ritz VDi, 2013, Diesel   ₹ 4,15,000
# 9580  Hyundai Verna VTVT 1.6 AT SX Option, 2019, Petrol   ₹ 8,55,000
# 9581         Hyundai New i20 1.2 Asta IVT, 2021, Petrol   ₹ 6,99,000
#
# [8858 rows x 11 columns]

# %%
df = df.drop(["AdditionInfo", "PostedDate", "Year"], axis=1)

# %%
df
# Out:
#               Brand      model  Age     kmDriven Transmission   Owner  \
# 0             Honda       City   23    98,000 km       Manual  second
# 1            Toyota     Innova   15  190000.0 km       Manual  second
# 2        Volkswagen  VentoTest   14    77,246 km       Manual   first
# 3     Maruti Suzuki      Swift    7    83,500 km       Manual  second
# 4     Maruti Suzuki     Baleno    5    45,000 km    Automatic   first
# ...             ...        ...  ...          ...          ...     ...
# 9577          Skoda    Octavia   10   105,904 km    Automatic  second
# 9578  Maruti Suzuki   Alto-800    4    55,000 km       Manual   first
# 9579  Maruti Suzuki       Ritz   11    92,000 km       Manual   first
# 9580        Hyundai      Verna    5    72,000 km    Automatic   first
# 9581        Hyundai    New i20    3    83,228 km       Manual  second
#
#         FuelType     AskPrice
# 0         Petrol   ₹ 1,95,000
# 1         Diesel   ₹ 3,75,000
# 2         Diesel   ₹ 1,84,999
# 3         Diesel   ₹ 5,65,000
# 4         Petrol   ₹ 6,85,000
# ...          ...          ...
# 9577      Diesel  ₹ 10,40,000
# 9578  Hybrid/CNG   ₹ 3,75,000
# 9579      Diesel   ₹ 4,15,000
# 9580      Petrol   ₹ 8,55,000
# 9581      Petrol   ₹ 6,99,000
#
# [8858 rows x 8 columns]

# %%
df["Brand"].value_counts().reset_index()
# Out:
#             Brand  count
# 0   Maruti Suzuki   2590
# 1         Hyundai   1437
# 2           Honda    730
# 3          Toyota    723
# 4        Mahindra    545
# 5            Tata    372
# 6   Mercedes-Benz    347
# 7      Volkswagen    278
# 8             BMW    256
# 9            Ford    231
# 10        Renault    226
# 11           Audi    191
# 12          Skoda    171
# 13            Kia    152
# 14      Chevrolet     84
# 15             MG     77
# 16         Nissan     71
# 17     Land Rover     70
# 18           Jeep     69
# 19          Volvo     46
# 20           Mini     33
# 21         Jaguar     30
# 22           Fiat     22
# 23         Datsun     22
# 24          Lexus     19
# 25        Porsche     18
# 26     Mitsubishi     17
# 27          Isuzu      9
# 28          Force      6
# 29     Ambassador      3
# 30    Rolls-Royce      2
# 31           Opel      2
# 32          Bajaj      2
# 33      Ssangyong      2
# 34   Aston Martin      1
# 35           ICML      1
# 36          Ashok      1
# 37        Bentley      1
# 38       Maserati      1

# %%
df["model"].value_counts().reset_index()
# Out:
#              model  count
# 0             City    306
# 1          Wagon-R    304
# 2            Swift    270
# 3           Ertiga    240
# 4            Creta    233
# ..             ...    ...
# 395        AMG A35      1
# 396     Vista Tech      1
# 397        Captiva      1
# 398   A3 Cabriolet      1
# 399  Leyland Stile      1
#
# [400 rows x 2 columns]

# %%
df["Transmission"].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df["Owner"].unique()
# Out:
# array(['second', 'first'], dtype=object)

# %%
df["FuelType"].unique()
# Out:
# array(['Petrol', 'Diesel', 'Hybrid/CNG'], dtype=object)

# %% [markdown]
# cateorical data to numerical

# %%
owner_map = {
    "first": 1,
    "second": 2,
    "third": 3,
    "fourth": 4
}

df["Owner"] = df["Owner"].map(owner_map)

# %%
df["Owner"]
# Out:
# 0       2
# 1       2
# 2       1
# 3       2
# 4       1
#        ..
# 9577    2
# 9578    1
# 9579    1
# 9580    1
# 9581    2
# Name: Owner, Length: 8858, dtype: int64

# %%
df["Transmission"] = df["Transmission"].map({
    "Manual": 0,
    "Automatic": 1
})

# %%
bool_cols = df.select_dtypes(include="bool").columns
df[bool_cols] = df[bool_cols].astype(int)

# %%
df = pd.get_dummies(
    df,
    columns=["FuelType"],

)

# %%
df["kmDriven"] = (
    df["kmDriven"]
    .str.replace(" km", "", regex=False)
    .str.replace(",", "", regex=False)
    .astype(float)
)

# %%
df["AskPrice"] = (
    df["AskPrice"]
    .str.replace("₹", "", regex=False)
    .str.replace(",", "", regex=False)
    .astype(int)
)

# %% [markdown]
# independent and depend variables

# %%
y = df["AskPrice"]
x=df.drop("AskPrice",axis=1)

# %% [markdown]
# visualization

# %%
X=df["Age"]
Y= df["AskPrice"]

# %%
# Line plot

X=df["kmDriven"]
Y= df["AskPrice"]
plt.scatter(X, Y)
plt.title("scatter Plot")
plt.show()

# %%
X=df["Age"]
Y= df["AskPrice"]
plt.scatter(X, Y)
plt.title("Scatter Plot")
plt.show()

# %%
df
# Out:
#               Brand      model  Age  kmDriven  Transmission  Owner  AskPrice  \
# 0             Honda       City   23   98000.0             0      2    195000
# 1            Toyota     Innova   15  190000.0             0      2    375000
# 2        Volkswagen  VentoTest   14   77246.0             0      1    184999
# 3     Maruti Suzuki      Swift    7   83500.0             0      2    565000
# 4     Maruti Suzuki     Baleno    5   45000.0             1      1    685000
# ...             ...        ...  ...       ...           ...    ...       ...
# 9577          Skoda    Octavia   10  105904.0             1      2   1040000
# 9578  Maruti Suzuki   Alto-800    4   55000.0             0      1    375000
# 9579  Maruti Suzuki       Ritz   11   92000.0             0      1    415000
# 9580        Hyundai      Verna    5   72000.0             1      1    855000
# 9581        Hyundai    New i20    3   83228.0             0      2    699000
#
#       FuelType_Diesel  FuelType_Hybrid/CNG  FuelType_Petrol
# 0               False                False             True
# 1                True                False            False
# 2                True                False            False
# 3                True                False            False
# 4               False                False             True
# ...               ...                  ...              ...
# 9577             True                False            False
# 9578            False                 True            False
# 9579             True                False            False
# 9580            False                False             True
# 9581            False                False             True
#
# [8858 rows x 10 columns]

# %%
# Box plot
plt.boxplot(df["AskPrice"])
plt.title("Box Plot")
plt.show()

# %%
# Histogram (distplot/deprecated → use displot)
sns.histplot(df['Age'])
plt.title("Histogram of Age")
plt.show()
